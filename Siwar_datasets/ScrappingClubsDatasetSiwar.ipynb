# %%
import numpy as np
import pandas as pd
import os
import glob
import random
import scipy
from faker import Faker
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.offline as py
from plotly.offline import iplot, init_notebook_mode
import plotly.graph_objs as go
from IPython.display import Markdown, display
# Out:
# Index(['ranking', 'country', 'point score', '1 year change',
#        'previous point scored', 'symbol change'],
#       dtype='object')
# Columns before dropping: Index(['ranking', 'country', 'point score', '1 year change',
#        'previous point scored', 'symbol change'],
#       dtype='object')
# Columns after dropping: Index(['ranking', 'country', 'point score', '1 year change',
#        'previous point scored'],
#       dtype='object')

# %%
import numpy as np
import pandas as pd
import os
import glob
import random
import scipy
from faker import Faker
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.offline as py
from plotly.offline import iplot, init_notebook_mode
import plotly.graph_objs as go
from IPython.display import Markdown, display

# Initialize Plotly for offline mode
init_notebook_mode(connected=True)

# Print the location of the scipy package
print(scipy.__file__)  # Should point to site-packages/scipy

# Path to the extracted folder
extract_folder = "Clubs_Datasets"

# List all files in the extracted folder (including subdirectories)
for root, dirs, files in os.walk(extract_folder):
    print(f"Directory: {root}")
    for file in files:
        print(f"  - {file}")

# Corrected path to the extracted subfolder
extract_folder = "Clubs_Datasets\\Clubs Datasets"

# Load CSV and XLSX files
csv_files = glob.glob(os.path.join(extract_folder, "*.csv"))
xlsx_files = glob.glob(os.path.join(extract_folder, "*.xlsx"))

# Display the files found
print(f"✅ CSV Files Found: {len(csv_files)}")
print(f"✅ XLSX Files Found: {len(xlsx_files)}")

# Load CSV files into a dictionary of DataFrames
csv_dfs = {os.path.basename(file): pd.read_csv(file, encoding='ISO-8859-1') for file in csv_files}
xlsx_dfs = {os.path.basename(file): pd.read_excel(file) for file in xlsx_files}

# Combine both dictionaries
dfs = {**csv_dfs, **xlsx_dfs}

# Print the number of datasets loaded
print(f"✅ Successfully loaded {len(dfs)} datasets.")

# 📌 Display first few rows of each dataset
print("\n📊 **Data at a Glance**")
for file, df in dfs.items():
    print(f"\n📌 Dataset: {file} | Shape: {df.shape}")
    display(df.head())  # Display first 5 rows nicely

# Load specific datasets
soccer_ranking = pd.read_csv(r"C:/Users/MSI/OneDrive - ESPRIT/Bureau/4DS ESPRIT/SEM2/PI PROJECT/Scrap Datasets/Clubs Datasets/Soccer_Football Clubs Ranking in june.csv", encoding='ISO-8859-1')
national_football_clubs_2013 = pd.read_excel('C:/Users/MSI/OneDrive - ESPRIT/Bureau/4DS ESPRIT/SEM2/PI PROJECT/Scrap Datasets/Clubs Datasets/2013 national-football-clubs.xlsx')
kenya_football_club_2014 = pd.read_excel('C:/Users/MSI/OneDrive - ESPRIT/Bureau/4DS ESPRIT/SEM2/PI PROJECT/Scrap Datasets/Clubs Datasets/2014 Kenya football club.xlsx')
football_clubs_ke_2015 = pd.read_excel('C:/Users/MSI/OneDrive - ESPRIT/Bureau/4DS ESPRIT/SEM2/PI PROJECT/Scrap Datasets/Clubs Datasets/2015 Football clubs KE.xlsx')

# Function to impute missing values based on column types
def impute_missing_values(df):
    for col in df.columns:
        if df[col].dtype == 'object':
            mode_value = df[col].mode()[0] if not df[col].isnull().all() else 'Unknown'
            df[col].fillna(mode_value, inplace=True)
        elif df[col].dtype in ['int64', 'float64']:
            if df[col].nunique() < 10:  # categorical
                mean_value = df[col].mean()
                df[col].fillna(mean_value, inplace=True)
            else:
                median_value = df[col].median()
                df[col].fillna(median_value, inplace=True)
    return df

# Apply the function to all datasets
soccer_ranking = impute_missing_values(soccer_ranking)
national_football_clubs_2013 = impute_missing_values(national_football_clubs_2013)
kenya_football_club_2014 = impute_missing_values(kenya_football_club_2014)
football_clubs_ke_2015 = impute_missing_values(football_clubs_ke_2015)

# Combine the scraped datasets (imputed) into a single dataset
scraped_data_combined = pd.concat([soccer_ranking, national_football_clubs_2013, kenya_football_club_2014, football_clubs_ke_2015], ignore_index=True)
print(soccer_ranking.columns)
soccer_ranking.columns = soccer_ranking.columns.str.strip()  # Remove spaces around column names




# Clean column names by stripping whitespace
scraped_data_combined.columns = scraped_data_combined.columns.str.strip()

# Print column names to verify
print("Columns before dropping:", scraped_data_combined.columns)

# Safely drop specified columns
columns_to_drop = [
    '2013 National Division One', 'country', 'club name', 'symbol change', 
    '2013 Kenya Premier League', '2013 unknown', 
    'Kenyan Premier League (1. League)', 'National Super League (2. League)', 
    'National Division One (3. League)', 'unkown', '2015 FISA Nairobi', 
    '2015 FKF Premier League', '2015 New Division'
]
# Drop the specified columns safely
scraped_data_combined.drop(columns=columns_to_drop, axis=1, inplace=True, errors='ignore')

# Verify that 'symbol change' column has been removed
if 'symbol change' in scraped_data_combined.columns:
    scraped_data_combined = scraped_data_combined.drop(columns=['symbol change'])
    print("Dropped 'symbol change' column.")
else:
    print("'symbol change' column does not exist or has already been dropped.")

if 'club name' in soccer_ranking.columns:
    soccer_ranking = soccer_ranking.drop(columns=['club name'])
print(soccer_ranking.head())  # Verify that 'club name' column has been removed

# Print column names after dropping
print("Columns after dropping:", scraped_data_combined.columns)


# Generate 100 records for the relevant columns
fake = Faker()



# African countries and their corresponding city, league, stadium, and real club names
country_city_league_stadium_mapping = {
    "Algeria": {"city": "Algiers", "league": "Algerian Ligue 1", "stadium": "Stade 5 Juillet 1962", "club_name": "CR Belouizdad"},
    "South Africa": {"city": "Johannesburg", "league": "South African Premier Division", "stadium": "FNB Stadium", "club_name": "Orlando Pirates"},
    "Morocco": {"city": "Casablanca", "league": "Moroccan Botola Pro", "stadium": "Stade Mohammed V", "club_name": "Wydad Casablanca"},
    "Nigeria": {"city": "Abuja", "league": "Nigeria Professional Football League (NPFL)", "stadium": "National Stadium", "club_name": "Enyimba FC"},
    "Kenya": {"city": "Nairobi", "league": "Kenyan Premier League", "stadium": "Moi International Sports Centre", "club_name": "Gor Mahia"},
    "Egypt": {"city": "Cairo", "league": "Egyptian Premier League", "stadium": "Cairo International Stadium", "club_name": "Al Ahly SC"},
    "Ghana": {"city": "Accra", "league": "Ghana Premier League", "stadium": "Accra Sports Stadium", "club_name": "Asante Kotoko"},
    "Côte d'Ivoire": {"city": "Abidjan", "league": "Ligue 1", "stadium": "Stade Félix-Houphouët-Boigny", "club_name": "Asec Mimosas"},
    "Ethiopia": {"city": "Addis Ababa", "league": "Ethiopian Premier League", "stadium": "Addis Ababa Stadium", "club_name": "St. George SC"},
    "Uganda": {"city": "Kampala", "league": "Ugandan Premier League", "stadium": "Namboole Stadium", "club_name": "KCCA FC"},
    "Senegal": {"city": "Dakar", "league": "Ligue 1", "stadium": "Stade Leopold Sedar Senghor", "club_name": "TP Mazembe"},
    "Cameroon": {"city": "Yaoundé", "league": "Cameroon Elite One", "stadium": "Stade Omnisports", "club_name": "Coton Sport"},
    "Tunisia": {"city": "Tunis", "league": "Tunisian Ligue Professionnelle 1", "stadium": "Stade Olympique de Radès", "club_name": "Espérance ST"},
    "Mali": {"city": "Bamako", "league": "Malian Première Division", "stadium": "Stade du 26 Mars", "club_name": "AS Real Bamako"},
    "Zambia": {"city": "Lusaka", "league": "Zambian Premier League", "stadium": "National Heroes Stadium", "club_name": "Zesco United"},
    "Angola": {"city": "Luanda", "league": "Girabola", "stadium": "Estádio 11 de Novembro", "club_name": "Petro de Luanda"},
    "Togo": {"city": "Lomé", "league": "Togolese Championnat National", "stadium": "Stade de Kégué", "club_name": "Togoport FC"},
    "Ivory Coast": {"city": "Abidjan", "league": "Ivory Coast Ligue 1", "stadium": "Stade Félix-Houphouët-Boigny", "club_name": "Stade d'Abidjan"},
    "Zimbabwe": {"city": "Harare", "league": "Zimbabwe Premier Soccer League", "stadium": "National Sports Stadium", "club_name": "Dynamos FC"},
    "Liberia": {"city": "Monrovia", "league": "Liberian Premier League", "stadium": "Antoinette Tubman Stadium", "club_name": "LISCR FC"},
    "Sierra Leone": {"city": "Freetown", "league": "Sierra Leone National Premier League", "stadium": "Siaka Stevens Stadium", "club_name": "East End Lions"},
    "Benin": {"city": "Cotonou", "league": "Benin Premier League", "stadium": "Stade de l'Amitié", "club_name": "Coton FC"},
    "Botswana": {"city": "Gaborone", "league": "Botswana Premier League", "stadium": "National Stadium", "club_name": "Gaborone United"},
    "Gabon": {"city": "Libreville", "league": "Gabon Championnat National D1", "stadium": "Stade de l'Amitié", "club_name": "Missile FC"},
    "Burkina Faso": {"city": "Ouagadougou", "league": "Burkina Faso Premier League", "stadium": "Stade du 4-Août", "club_name": "ASFA Yennenga"},
    "Republic of the Congo": {"city": "Brazzaville", "league": "Ligue 1", "stadium": "Stade Alphonse-Massamba-Débat", "club_name": "AC Léopards"},
    "Congo DR": {"city": "Kinshasa", "league": "Ligue 1", "stadium": "Stade des Martyrs", "club_name": "TP Mazembe"},
    "Mauritius": {"city": "Port Louis", "league": "Mauritius Premier League", "stadium": "Stade Anjalay", "club_name": "ASPL 2000"},
    "Madagascar": {"city": "Antananarivo", "league": "Madagascar Pro League", "stadium": "Stade de Mahamasina", "club_name": "Fosa Juniors FC"}
}



formations = ['4-3-3', '4-4-2', '3-5-2', '4-2-3-1', '3-4-3', '5-3-2', '4-5-1', '4-1-4-1', '3-2-4-1', '4-4-1-1']

playing_styles = [
    'Possession-based', 
    'Counter-attacking', 
    'Direct', 
    'Defensive', 
    'Pressing', 
    'Fast Counter-Attacking', 
    'Physical and Powerful Play', 
    'Creative Dribbling', 
    'High Pressing', 
    'Possession-Based Play', 
    'Direct Play and Long Balls', 
    'Wing Play and Width', 
    'Compact Defending', 
    'High Intensity', 
    'Set Piece Threat'
]
scouting_focus = [
    'Youth development', 
    'Scouting in South America', 
    'Scouting in Africa', 
    'Scouting in Europe', 
    'Physical Attributes', 
    'Technical Skills', 
    'Tactical Awareness', 
    'Mental Toughness', 
    'Versatility', 
    'Work Rate and Attitude', 
    'Youth Development Potential', 
    'Aerial Ability', 
    'Mentality and Leadership', 
    'Potential for International Play', 
    'Attacking Creativity', 
    'Defensive Solidity', 
    'Club and League Experience', 
    'Cultural and Personality Fit', 
    'Injury Record and Longevity'
]
transfer_histories = [
    'Bought 10 players, Sold 5 players', 
    'Minimal transfer activity', 
    'Bought 3 players, Sold 2 players', 
    'Domestic Transfers', 
    'International Transfers', 
    'Player Development and Youth Transfers', 
    'Transfers to European Leagues', 
    'Transfers to Middle Eastern Leagues', 
    'Transfers to North African Leagues', 
    'High-Profile African Transfers', 
    'Transfers for National Team Duty', 
    'Loan Moves', 
    'Transfer Window Trends', 
    'Transfer Speculation and Rumors', 
    'Transfers Due to Political or Economic Factors', 
    'End of Career Transfers', 
    'Transfer Fees and Market Growth'
]
historical_coaches = [
    'Sir Alex Ferguson', 
    'Carlo Ancelotti', 
    'Jose Mourinho', 
    'Pep Guardiola', 
    'Hassan Shehata',
    'Herve Renard', 
    'Claude Le Roy', 
    'Stephen Keshi', 
    'Giorgio Meneghetti', 
    'Mohamed Fawzi', 
    'Shaukat Ali', 
    'Manuel José', 
    'Carlos Queiroz', 
    'Clemente Lisi', 
    'Rabah Saâdane', 
    'Eckhard Krautzun', 
    'French Michel Dussuyer', 
    'Bobby Williamson', 
    'Pierre Lechantre', 
    'Bruce Grobbelaar', 
    'Kwesi Appiah', 
    'Vahid Halilhodžić', 
    'Luis Fernandez', 
    'Javier Clemente', 
    'Pitso Mosimane', 
    'Henryk Kasperczak', 
    'Roger Lemerre', 
    'Faouzi Benzarti', 
    'Maher Kanzari', 
    'Nabil Maâloul', 
    'Ali Kaabi', 
    'Ben Ammar'
]
sponsorship_deals = [
    'MTN and CAF (Confederation of African Football)', 
    'Nike and Various African National Teams', 
    'Coca-Cola and CAF', 
    'Vodafone and Egypt National Football Team', 
    'Pepsi and Various African Football Teams', 
    'TotalEnergies and CAF', 
    'Samsung and Various African Clubs', 
    'Fly Emirates and Various African Clubs', 
    'Puma and African National Teams', 
    'Absa Bank and South African Football', 
    'Orange and Various African Football Competitions', 
    'Betway and Various African Football Teams', 
    'Adidas and CAF', 
    'Qatar Airways and Al Ahly (Egypt)', 
    'MTN and South African Football'
]
social_media_links = [
    'Facebook: CAF (Confederation of African Football) - https://www.facebook.com/CAFonline',
    'Twitter: CAF (Confederation of African Football) - https://twitter.com/CAF_Online',
    'Instagram: Yaya Touré - https://www.instagram.com/yaya_toure/',
    'Instagram: African Cup of Nations (AFCON) - https://www.instagram.com/caf_online/',
    'YouTube: SuperSport - https://www.youtube.com/user/SuperSportTV',
    'YouTube: CAF TV - https://www.youtube.com/channel/UCpA2VbdYfmH7pGGLzY6gwFA',
    'TikTok: Khaby Lame - https://www.tiktok.com/@khaby.lame',
    'LinkedIn: Amaju Pinnick - https://www.linkedin.com/in/amaju-pinnick-85b3b9117/',
    'WhatsApp: Various football club and team groups (private)',
    'Snapchat: Bonang Matheba - https://www.snapchat.com/add/bonang_m',
    'Telegram: CAF News - https://t.me/CAF_News'
]

# Create a DataFrame for African countries and their corresponding cities, leagues,stadiums and club_names
countries = list(country_city_league_stadium_mapping.keys())
cities = [country_city_league_stadium_mapping[country]["city"] for country in countries]
leagues = [country_city_league_stadium_mapping[country]["league"] for country in countries]
stadiums = [country_city_league_stadium_mapping[country]["stadium"] for country in countries]
club_names = [country_city_league_stadium_mapping[country]["club_name"] for country in countries]

african_football_clubs = pd.DataFrame({
    "Country": countries,
    "City": cities,
    "League": leagues,
    "Stadium": stadiums,
    "Club Name": club_names,
    "Formation": [random.choice(formations) for _ in range(len(countries))],
    "Playing Style": [random.choice(playing_styles) for _ in range(len(countries))],
    "Scouting Focus": [random.choice(scouting_focus) for _ in range(len(countries))],
    "Transfer History": [random.choice(transfer_histories) for _ in range(len(countries))],
    "Historical Coaches": [random.choice(historical_coaches) for _ in range(len(countries))],
    "Sponsorship Deals": [random.choice(sponsorship_deals) for _ in range(len(countries))],
    "Social Media Links": [random.choice(social_media_links) for _ in range(len(countries))],
})
# Display the updated DataFrame
print(african_football_clubs)

# Now, combine the scraped data with the generated fake data
final_data = pd.concat([scraped_data_combined, african_football_clubs], ignore_index=True)




# Drop the specified columns from the DataFrame
final_data.drop(columns=columns_to_drop, axis=1, inplace=True, errors='ignore')

# Apply imputation to ensure no missing values
final_data = impute_missing_values(final_data)

# Save the final dataset to a CSV file
file_path = "clubs_football_data_Siwar.csv"
final_data.to_csv(file_path, index=False)
print(soccer_ranking.columns)
soccer_ranking.columns = soccer_ranking.columns.str.strip()
print("Columns before dropping:", soccer_ranking.columns)
soccer_ranking.drop(columns=['symbol change'], axis=1, inplace=True, errors='ignore')
print("Columns after dropping:", soccer_ranking.columns)
# Print confirmation
print(f"✅ Combined dataset has been successfully saved to {file_path}")
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         </script>
#         <script type="module">import "https://cdn.plot.ly/plotly-3.0.0.min"</script>
# c:\Users\MSI\AppData\Local\Programs\Python\Python313\Lib\site-packages\scipy\__init__.py
# ✅ CSV Files Found: 0
# ✅ XLSX Files Found: 0
# ✅ Successfully loaded 0 datasets.
#
# 📊 **Data at a Glance**
# Index(['ranking', 'club name\r', 'country', 'point score\r\n',
#        '1 year change\r', 'previous point scored\r\n', 'symbol change\r\n'],
#       dtype='object')
# Columns before dropping: Index(['ranking', 'club name', 'country', 'point score', '1 year change',
#        'previous point scored', 'symbol change', '2013 Kenya Premier League',
#        '2013 National Division One', '2013 unknown',
#        'Kenyan Premier League (1. League)',
# ...
